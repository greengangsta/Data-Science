# %%
import numpy as np 
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('AirQualityUCI.xlsx',index_col = 'Date',parse_dates = True)

# %%
data.columns
# Out:
# Index(['Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %%
data.head()
# Out:
#                 Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# Date
# 2004-03-10  18:00:00     2.6      1360.00       150  11.881723        1045.50
# 2004-03-10  19:00:00     2.0      1292.25       112   9.397165         954.75
# 2004-03-10  20:00:00     2.2      1402.00        88   8.997817         939.25
# 2004-03-10  21:00:00     2.2      1375.50        80   9.228796         948.25
# 2004-03-10  22:00:00     1.6      1272.25        51   6.518224         835.50
#
#             NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T  \
# Date
# 2004-03-10    166.0       1056.25    113.0       1692.00      1267.50  13.60
# 2004-03-10    103.0       1173.75     92.0       1558.75       972.25  13.30
# 2004-03-10    131.0       1140.00    114.0       1554.50      1074.00  11.90
# 2004-03-10    172.0       1092.00    122.0       1583.75      1203.25  11.00
# 2004-03-10    131.0       1205.00    116.0       1490.00      1110.00  11.15
#
# ...

# %%
data.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %%
data['Day'] = pd.DatetimeIndex(data['Date']).day
data['month'] = pd.DatetimeIndex(data['Date']).month
data['year'] = pd.DatetimeIndex(data['Date']).year

# %%
data = data.drop(columns = ['Date','Time'])
data.columns
# Out:
# Index(['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)',
#        'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)',
#        'T', 'RH', 'AH', 'Day', 'month', 'year'],
#       dtype='object')

# %%
plt.figure(figsize= (15,10))

plt.subplot(311)
data["CO(GT)"].plot(kind = 'line')

plt.subplot(312)
data["NOx(GT)"].plot(kind = 'line')

plt.subplot(313)
data["C6H6(GT)"].plot(kind = 'line')

# %%
import seaborn as sns
import dateutil
#data = data.drop(columns = ['Time'])
cols = ['CO(GT)','NOx(GT)','C6H6(GT)']
data1 = data[cols]

# %%
plt.figure(figsize= (15,10))
sns.lineplot(data = data1)

# %%
data['CO(GT)'].plot.hist(bins = 20,edgecolor = 'k')

# %%
data['NOx(GT)'].plot.hist(bins = 20, edgecolor = 'k')

# %%
data['C6H6(GT)'].plot.hist(bins =20,edgecolor = 'k')

# %%
data.head(2).plot.barh(figsize =(15,8),edgecolor = 'k')

# %%
data.groupby('month')['NOx(GT)'].mean().plot.bar(edgecolor = 'k')

# %%
data.groupby('month')['C6H6(GT)'].mean().plot.bar(edgecolor = 'k')

# %%
data.groupby('month')['CO(GT)'].mean().plot.bar(edgecolor ='k' )

# %%
data.groupby('month')['CO(GT)','NOx(GT)','C6H6(GT)'].mean().plot.line(lw = 4,figsize = (15,6))

# %%
data['CO(GT)'].plot(figsize = (15,5))

# %%
data = data[(data['CO(GT)'] != -200) & (data['CO(GT)'] != None)]
data = data[(data['NOx(GT)'] != -200) & (data['NOx(GT)'] != None)]
data = data[(data['C6H6(GT)'] != -200) & (data['C6H6(GT)'] != None)]

# %%
data['CO(GT)'].plot(figsize = (15,5))
data.rolling(window= 7).mean()['CO(GT)'].plot()

# %%
data['NOx(GT)'].plot(figsize = (15,5))
data.rolling(window= 7).mean()['NOx(GT)'].plot()

# %%
data['C6H6(GT)'].plot(figsize = (15,5))
data.rolling(window= 7).mean()['C6H6(GT)'].plot()

# %%
data.groupby('month')['CO(GT)'].mean().plot.bar(edgecolor ='k' )

# %%
data.groupby('month')['NOx(GT)'].mean().plot.bar(edgecolor ='k' )

# %%
data.groupby('month')['C6H6(GT)'].mean().plot.bar(edgecolor ='k' )

# %%
co_data = pd.DataFrame(data['CO(GT)'],columns = ['CO(GT)'])
co_data.columns
co_data.head()
# Out:
#             CO(GT)
# Date
# 2004-03-10     2.6
# 2004-03-10     2.0
# 2004-03-10     2.2
# 2004-03-10     2.2
# 2004-03-10     1.6

# %%
co_data.plot(figsize = (15,6))

# %%
co_data['EWMA-7min'] =co_data['CO(GT)'].ewm(span = 7).mean()
co_data['EWMA-10min'] =co_data['CO(GT)'].ewm(span = 10).mean()

# %%
co_data.plot(figsize = (20,10))

# %%
co_data.index
# Out:
# DatetimeIndex(['2004-03-10', '2004-03-10', '2004-03-10', '2004-03-10',
#                '2004-03-10', '2004-03-10', '2004-03-11', '2004-03-11',
#                '2004-03-11', '2004-03-11',
#                ...
#                '2005-04-04', '2005-04-04', '2005-04-04', '2005-04-04',
#                '2005-04-04', '2005-04-04', '2005-04-04', '2005-04-04',
#                '2005-04-04', '2005-04-04'],
#               dtype='datetime64[ns]', name='Date', length=6944, freq=None)
